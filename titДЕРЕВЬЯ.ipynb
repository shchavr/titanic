# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

from IPython.display import HTML
style = "<style>svg{width:0.1% !important;height:0.1% !important;</style>"
HTML( style )

import os
os.environ["PATH"] += os.pathsep + "C:\\Program Files (x86)\\graphviz2.38\\bin" + os.pathsep + "C:\\Program Files (x86)\\graphviz2.38"

# %% [markdown]
# Подключаем

# %%
from sklearn import tree
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from graphviz  import Source
from IPython.display import SVG, display, HTML
style = "<style>svg{width: 100% !important; height: 100% !important;} </style>"

# %%
titanic_data = pd.read_csv("C:\\учеба\\Программирование\\DtaScience Stepik\\ТИТАНИК\\Titanic.csv")

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Сколько в каждой колонке пропущенных значений

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Отберем очевидные переменные.
# В X положили нужные коллонки
#
# В Y то, что будем предсказывать

# %%
X = titanic_data.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis = 1)
y = titanic_data.Survived

# %% [markdown]
# Изменение переменных, которые записаны в строках

# %%
X = pd.get_dummies(X)
X['Sex_female'] = X['Sex_female'].astype(int)
X['Sex_male'] = X['Sex_male'].astype(int)
X['Embarked_C'] = X['Embarked_C'].astype(int)
X['Embarked_Q'] = X['Embarked_Q'].astype(int)
X['Embarked_S'] = X['Embarked_S'].astype(int)

# %% [markdown]
# Заполняем пропущенные значения

# %%
X = X.fillna({'Age' : X.Age.median()})

# %%
X.isnull().sum()
# Out:
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  22.0      1      0   7.2500           0         1           0
# 1       1  38.0      1      0  71.2833           1         0           1
# 2       3  26.0      0      0   7.9250           1         0           0
# 3       1  35.0      1      0  53.1000           1         0           0
# 4       3  35.0      0      0   8.0500           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %% [markdown]
# Дерево решений

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# Оверфиттинг

# %%
plt.figure(figsize=(100, 25))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(0.6179446897644928, 0.975, 'Sex_female <= 0.5\nentropy = 0.961\nsamples = 891\nvalue = [549, 342]'),
#  Text(0.394630321557971, 0.925, 'Fare <= 26.269\nentropy = 0.699\nsamples = 577\nvalue = [468, 109]'),
#  Text(0.5062875056612319, 0.95, 'True  '),
#  Text(0.19551064311594202, 0.875, 'Age <= 13.5\nentropy = 0.558\nsamples = 415\nvalue = [361, 54]'),
#  Text(0.06702898550724638, 0.825, 'SibSp <= 2.0\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.059782608695652176, 0.775, 'Age <= 10.0\nentropy = 0.371\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.05253623188405797, 0.725, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.06702898550724638, 0.725, 'Fare <= 15.015\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.059782608695652176, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07427536231884058, 0.675, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07427536231884058, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3239923007246377, 0.825, 'Embarked_C <= 0.5\nentropy = 0.477\nsamples = 400\nvalue = [359, 41]'),
#  Text(0.2349411231884058, 0.775, 'Fare <= 13.25\nentropy = 0.437\nsamples = 355\nvalue = [323, 32]'),
#  Text(0.15285326086956522, 0.725, 'Fare <= 7.91\nentropy = 0.479\nsamples = 291\nvalue = [261, 30]'),
#  Text(0.08876811594202899, 0.675, 'Fare <= 7.865\nentropy = 0.353\nsamples = 150\nvalue = [140, 10]'),
#  Text(0.08152173913043478, 0.625, 'Age <= 32.5\nentropy = 0.424\nsamples = 116\nvalue = [106, 10]'),
#  Text(0.07427536231884058, 0.575, 'Age <= 20.75\nentropy = 0.507\nsamples = 89\nvalue = [79, 10]'),
#  Text(0.06702898550724638, 0.525, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.08152173913043478, 0.525, 'Fare <= 7.763\nentropy = 0.576\nsamples = 73\nvalue = [63, 10]'),
#  Text(0.03260869565217391, 0.475, 'Age <= 27.5\nentropy = 0.451\nsamples = 53\nvalue = [48, 5]'),
#  Text(0.014492753623188406, 0.425, 'Fare <= 7.013\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.007246376811594203, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.021739130434782608, 0.375, 'Fare <= 7.196\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.014492753623188406, 0.325, 'Fare <= 7.133\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.007246376811594203, 0.275, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.021739130434782608, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.028985507246376812, 0.325, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.050724637681159424, 0.425, 'Fare <= 7.744\nentropy = 0.31\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.043478260869565216, 0.375, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.057971014492753624, 0.375, 'Age <= 28.5\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.043478260869565216, 0.325, 'SibSp <= 0.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.036231884057971016, 0.275, 'entropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.050724637681159424, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07246376811594203, 0.325, 'Age <= 30.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06521739130434782, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07971014492753623, 0.275, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13043478260869565, 0.475, 'Age <= 31.5\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.12318840579710146, 0.425, 'Fare <= 7.798\nentropy = 0.742\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.11594202898550725, 0.375, 'Age <= 28.5\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.10869565217391304, 0.325, 'Age <= 26.5\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.09420289855072464, 0.275, 'Age <= 25.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.08695652173913043, 0.225, 'Age <= 21.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.07246376811594203, 0.175, 'Fare <= 7.785\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06521739130434782, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07971014492753623, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10144927536231885, 0.175, 'Age <= 24.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.09420289855072464, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10869565217391304, 0.125, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10144927536231885, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12318840579710146, 0.275, 'Age <= 27.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11594202898550725, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13043478260869565, 0.225, 'Fare <= 7.785\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12318840579710146, 0.175, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13768115942028986, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12318840579710146, 0.325, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13043478260869565, 0.375, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.13768115942028986, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08876811594202899, 0.575, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.09601449275362318, 0.625, 'entropy = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(0.21693840579710144, 0.675, 'Fare <= 7.988\nentropy = 0.589\nsamples = 141\nvalue = [121, 20]'),
#  Text(0.18115942028985507, 0.625, 'SibSp <= 1.5\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.17391304347826086, 0.575, 'Age <= 41.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.16666666666666666, 0.525, 'SibSp <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.15942028985507245, 0.475, 'Age <= 26.0\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.15217391304347827, 0.425, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.16666666666666666, 0.425, 'Age <= 31.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.15942028985507245, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17391304347826086, 0.375, 'Age <= 35.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.16666666666666666, 0.325, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.18115942028985507, 0.325, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17391304347826086, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18115942028985507, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18840579710144928, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25271739130434784, 0.625, 'Age <= 19.5\nentropy = 0.521\nsamples = 128\nvalue = [113, 15]'),
#  Text(0.21014492753623187, 0.575, 'Fare <= 8.104\nentropy = 0.722\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.1956521739130435, 0.525, 'Age <= 17.0\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.18840579710144928, 0.475, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2028985507246377, 0.475, 'Age <= 18.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1956521739130435, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21014492753623187, 0.425, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2246376811594203, 0.525, 'Age <= 18.5\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.21739130434782608, 0.475, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.2318840579710145, 0.475, 'Pclass <= 2.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2246376811594203, 0.425, 'Fare <= 11.75\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21739130434782608, 0.375, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2318840579710145, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2391304347826087, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.29528985507246375, 0.575, 'Age <= 26.5\nentropy = 0.475\nsamples = 108\nvalue = [97, 11]'),
#  Text(0.28804347826086957, 0.525, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.302536231884058, 0.525, 'Fare <= 8.081\nentropy = 0.592\nsamples = 77\nvalue = [66, 11]'),
#  Text(0.2608695652173913, 0.475, 'Age <= 31.25\nentropy = 0.371\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.2536231884057971, 0.425, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.26811594202898553, 0.425, 'Age <= 33.0\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.2608695652173913, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2753623188405797, 0.375, 'Age <= 44.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.26811594202898553, 0.325, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2826086956521739, 0.325, 'Age <= 47.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2753623188405797, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2898550724637681, 0.275, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3442028985507246, 0.475, 'Fare <= 8.238\nentropy = 0.688\nsamples = 49\nvalue = [40, 9]'),
#  Text(0.33695652173913043, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35144927536231885, 0.425, 'Fare <= 8.658\nentropy = 0.65\nsamples = 48\nvalue = [40, 8]'),
#  Text(0.3442028985507246, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.358695652173913, 0.375, 'Age <= 31.5\nentropy = 0.684\nsamples = 44\nvalue = [36, 8]'),
#  Text(0.32608695652173914, 0.325, 'Fare <= 10.0\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.30434782608695654, 0.275, 'Age <= 27.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2971014492753623, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3115942028985507, 0.225, 'Age <= 28.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.30434782608695654, 0.175, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3188405797101449, 0.175, 'Fare <= 9.492\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3115942028985507, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.32608695652173914, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.34782608695652173, 0.275, 'Fare <= 11.75\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.34057971014492755, 0.225, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.35507246376811596, 0.225, 'Age <= 30.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.34782608695652173, 0.175, 'Age <= 29.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.34057971014492755, 0.125, 'Age <= 27.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3333333333333333, 0.075, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34782608695652173, 0.075, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.35507246376811596, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.36231884057971014, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.391304347826087, 0.325, 'Fare <= 10.0\nentropy = 0.544\nsamples = 24\nvalue = [21, 3]'),
#  Text(0.38405797101449274, 0.275, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.39855072463768115, 0.275, 'Age <= 59.5\nentropy = 0.61\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.38405797101449274, 0.225, 'Fare <= 12.762\nentropy = 0.523\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.37681159420289856, 0.175, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.391304347826087, 0.175, 'Age <= 45.0\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.38405797101449274, 0.125, 'Age <= 40.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.37681159420289856, 0.075, 'Age <= 35.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3695652173913043, 0.025, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38405797101449274, 0.025, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.391304347826087, 0.075, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.39855072463768115, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.41304347826086957, 0.225, 'Age <= 64.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4057971014492754, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42028985507246375, 0.175, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3170289855072464, 0.725, 'Fare <= 22.887\nentropy = 0.201\nsamples = 64\nvalue = [62, 2]'),
#  Text(0.30978260869565216, 0.675, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(0.3242753623188406, 0.675, 'Fare <= 23.35\nentropy = 0.381\nsamples = 27\nvalue = [25, 2]'),
#  Text(0.3170289855072464, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.33152173913043476, 0.625, 'Age <= 33.0\nentropy = 0.235\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.3242753623188406, 0.575, 'Age <= 31.5\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.3170289855072464, 0.525, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.33152173913043476, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.338768115942029, 0.575, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.41304347826086957, 0.775, 'Fare <= 15.148\nentropy = 0.722\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.39855072463768115, 0.725, 'Age <= 29.5\nentropy = 0.552\nsamples = 39\nvalue = [34, 5]'),
#  Text(0.391304347826087, 0.675, 'Age <= 28.75\nentropy = 0.65\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.38405797101449274, 0.625, 'Age <= 22.5\nentropy = 0.579\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.358695652173913, 0.575, 'Age <= 18.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.35144927536231885, 0.525, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36594202898550726, 0.525, 'Fare <= 5.619\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.358695652173913, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37318840579710144, 0.475, 'Fare <= 7.227\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.36594202898550726, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3804347826086957, 0.425, 'Age <= 21.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.37318840579710144, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38768115942028986, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.40942028985507245, 0.575, 'Pclass <= 2.5\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.39492753623188404, 0.525, 'Fare <= 14.454\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38768115942028986, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40217391304347827, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.42391304347826086, 0.525, 'Fare <= 7.227\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.4166666666666667, 0.475, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4311594202898551, 0.475, 'Fare <= 7.562\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.42391304347826086, 0.425, 'Age <= 25.75\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4166666666666667, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4311594202898551, 0.375, 'Age <= 28.25\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.42391304347826086, 0.325, 'entropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4384057971014493, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4384057971014493, 0.425, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.39855072463768115, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4057971014492754, 0.675, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.427536231884058, 0.725, 'Fare <= 20.233\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.42028985507246375, 0.675, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.43478260869565216, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.59375, 0.875, 'SibSp <= 2.5\nentropy = 0.924\nsamples = 162\nvalue = [107.0, 55.0]'),
#  Text(0.5720108695652174, 0.825, 'Age <= 13.5\nentropy = 0.964\nsamples = 139\nvalue = [85.0, 54.0]'),
#  Text(0.5647644927536232, 0.775, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5792572463768116, 0.775, 'Fare <= 26.469\nentropy = 0.939\nsamples = 132\nvalue = [85, 47]'),
#  Text(0.5720108695652174, 0.725, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5865036231884058, 0.725, 'Age <= 53.0\nentropy = 0.921\nsamples = 128\nvalue = [85, 43]'),
#  Text(0.5027173913043478, 0.675, 'Fare <= 26.775\nentropy = 0.956\nsamples = 106\nvalue = [66, 40]'),
#  Text(0.48188405797101447, 0.625, 'Age <= 46.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.4746376811594203, 0.575, 'Embarked_C <= 0.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.4673913043478261, 0.525, 'Age <= 39.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4601449275362319, 0.475, 'Age <= 31.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4528985507246377, 0.425, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4673913043478261, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4746376811594203, 0.475, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.48188405797101447, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4891304347826087, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5235507246376812, 0.625, 'Fare <= 29.1\nentropy = 0.925\nsamples = 97\nvalue = [64, 33]'),
#  Text(0.5163043478260869, 0.575, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5307971014492754, 0.575, 'Fare <= 30.598\nentropy = 0.954\nsamples = 88\nvalue = [55, 33]'),
#  Text(0.4963768115942029, 0.525, 'Age <= 28.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.4891304347826087, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5036231884057971, 0.475, 'Fare <= 30.285\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4963768115942029, 0.425, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5108695652173914, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5652173913043478, 0.525, 'Fare <= 52.277\nentropy = 0.918\nsamples = 78\nvalue = [52, 26]'),
#  Text(0.532608695652174, 0.475, 'Age <= 47.5\nentropy = 0.619\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.5253623188405797, 0.425, 'Fare <= 36.125\nentropy = 0.529\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.5181159420289855, 0.375, 'Fare <= 35.25\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.5036231884057971, 0.325, 'Embarked_C <= 0.5\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4963768115942029, 0.275, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5108695652173914, 0.275, 'Fare <= 30.848\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5036231884057971, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5181159420289855, 0.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.532608695652174, 0.325, 'Age <= 36.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5253623188405797, 0.275, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5398550724637681, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.532608695652174, 0.375, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.5398550724637681, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5978260869565217, 0.475, 'Fare <= 59.087\nentropy = 0.983\nsamples = 52\nvalue = [30.0, 22.0]'),
#  Text(0.5615942028985508, 0.425, 'Age <= 22.0\nentropy = 0.896\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.5543478260869565, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5688405797101449, 0.375, 'Age <= 49.5\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.5615942028985508, 0.325, 'Age <= 27.5\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.5543478260869565, 0.275, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5688405797101449, 0.275, 'Age <= 29.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.5615942028985508, 0.225, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5760869565217391, 0.225, 'Fare <= 54.798\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5688405797101449, 0.175, 'Fare <= 52.827\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5615942028985508, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5760869565217391, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5833333333333334, 0.175, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5760869565217391, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6340579710144928, 0.425, 'Fare <= 379.925\nentropy = 0.888\nsamples = 36\nvalue = [25, 11]'),
#  Text(0.6268115942028986, 0.375, 'Fare <= 134.642\nentropy = 0.834\nsamples = 34\nvalue = [25, 9]'),
#  Text(0.6195652173913043, 0.325, 'Fare <= 86.29\nentropy = 0.906\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.5978260869565217, 0.275, 'Embarked_C <= 0.5\nentropy = 0.65\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.5905797101449275, 0.225, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.605072463768116, 0.225, 'Fare <= 77.965\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.5978260869565217, 0.175, 'Fare <= 62.369\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5905797101449275, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.605072463768116, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6123188405797102, 0.175, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6413043478260869, 0.275, 'Embarked_S <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.6340579710144928, 0.225, 'Fare <= 89.552\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6268115942028986, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6413043478260869, 0.175, 'Age <= 34.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6340579710144928, 0.125, 'Fare <= 99.99\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6268115942028986, 0.075, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6413043478260869, 0.075, 'Age <= 17.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6340579710144928, 0.025, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6485507246376812, 0.025, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6485507246376812, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6485507246376812, 0.225, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6340579710144928, 0.325, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6413043478260869, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6702898550724637, 0.675, 'Age <= 75.5\nentropy = 0.575\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.6630434782608695, 0.625, 'Embarked_C <= 0.5\nentropy = 0.454\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.6557971014492754, 0.575, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6702898550724637, 0.575, 'SibSp <= 0.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.6630434782608695, 0.525, 'Age <= 57.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.6557971014492754, 0.475, 'Fare <= 33.098\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6485507246376812, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6630434782608695, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6702898550724637, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.677536231884058, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.677536231884058, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6154891304347826, 0.825, 'Age <= 3.5\nentropy = 0.258\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.6082427536231884, 0.775, 'Age <= 2.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6009963768115942, 0.725, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6154891304347826, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6227355072463768, 0.775, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.8412590579710145, 0.925, 'Pclass <= 2.5\nentropy = 0.824\nsamples = 314\nvalue = [81.0, 233.0]'),
#  Text(0.7296018738677537, 0.95, '  False'),
#  Text(0.7391304347826086, 0.875, 'Fare <= 28.856\nentropy = 0.299\nsamples = 170\nvalue = [9, 161]'),
#  Text(0.7246376811594203, 0.825, 'Fare <= 28.231\nentropy = 0.469\nsamples = 70\nvalue = [7, 63]'),
#  Text(0.717391304347826, 0.775, 'Age <= 23.5\nentropy = 0.426\nsamples = 69\nvalue = [6.0, 63.0]'),
#  Text(0.7101449275362319, 0.725, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.7246376811594203, 0.725, 'Age <= 27.5\nentropy = 0.503\nsamples = 54\nvalue = [6, 48]'),
#  Text(0.7065217391304348, 0.675, 'Age <= 25.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.6920289855072463, 0.625, 'Fare <= 13.75\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6847826086956522, 0.575, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6992753623188406, 0.575, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7210144927536232, 0.625, 'Fare <= 17.429\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7137681159420289, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7282608695652174, 0.575, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7427536231884058, 0.675, 'Age <= 37.0\nentropy = 0.365\nsamples = 43\nvalue = [3, 40]'),
#  Text(0.7355072463768116, 0.625, 'entropy = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.75, 0.625, 'Age <= 39.0\nentropy = 0.629\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.7427536231884058, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7572463768115942, 0.575, 'Age <= 56.0\nentropy = 0.503\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.7427536231884058, 0.525, 'SibSp <= 0.5\nentropy = 0.337\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.7355072463768116, 0.475, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.75, 0.475, 'Age <= 44.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7427536231884058, 0.425, 'Age <= 43.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7355072463768116, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7572463768115942, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7717391304347826, 0.525, 'Age <= 57.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7644927536231884, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7789855072463768, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7318840579710145, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7536231884057971, 0.825, 'Age <= 2.5\nentropy = 0.141\nsamples = 100\nvalue = [2, 98]'),
#  Text(0.7463768115942029, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7608695652173914, 0.775, 'Parch <= 1.5\nentropy = 0.081\nsamples = 99\nvalue = [1, 98]'),
#  Text(0.7536231884057971, 0.725, 'entropy = 0.0\nsamples = 84\nvalue = [0, 84]'),
#  Text(0.7681159420289855, 0.725, 'Age <= 24.5\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.7608695652173914, 0.675, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.7753623188405797, 0.675, 'Age <= 28.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7681159420289855, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.782608695652174, 0.625, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9433876811594203, 0.875, 'Fare <= 23.35\nentropy = 1.0\nsamples = 144\nvalue = [72, 72]'),
#  Text(0.9157608695652174, 0.825, 'Age <= 36.5\nentropy = 0.977\nsamples = 117\nvalue = [48, 69]'),
#  Text(0.8822463768115942, 0.775, 'Embarked_S <= 0.5\nentropy = 0.959\nsamples = 110\nvalue = [42, 68]'),
#  Text(0.8369565217391305, 0.725, 'Fare <= 15.621\nentropy = 0.86\nsamples = 53\nvalue = [15, 38]'),
#  Text(0.8297101449275363, 0.675, 'Fare <= 13.935\nentropy = 0.918\nsamples = 45\nvalue = [15, 30]'),
#  Text(0.7971014492753623, 0.625, 'Age <= 17.0\nentropy = 0.758\nsamples = 32\nvalue = [7, 25]'),
#  Text(0.7898550724637681, 0.575, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8043478260869565, 0.575, 'Age <= 18.5\nentropy = 0.855\nsamples = 25\nvalue = [7.0, 18.0]'),
#  Text(0.7971014492753623, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8115942028985508, 0.525, 'Parch <= 1.0\nentropy = 0.811\nsamples = 24\nvalue = [6, 18]'),
#  Text(0.8043478260869565, 0.475, 'Age <= 29.25\nentropy = 0.755\nsamples = 23\nvalue = [5, 18]'),
#  Text(0.7971014492753623, 0.425, 'Fare <= 8.008\nentropy = 0.684\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.7898550724637681, 0.375, 'Fare <= 7.769\nentropy = 0.592\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.782608695652174, 0.325, 'Age <= 21.5\nentropy = 0.722\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.7753623188405797, 0.275, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7898550724637681, 0.275, 'Fare <= 7.681\nentropy = 0.592\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.7753623188405797, 0.225, 'Embarked_C <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7681159420289855, 0.175, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.782608695652174, 0.175, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8043478260869565, 0.225, 'Fare <= 7.744\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.7971014492753623, 0.175, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8115942028985508, 0.175, 'Age <= 25.0\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.8043478260869565, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8188405797101449, 0.125, 'entropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.7971014492753623, 0.325, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8043478260869565, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8115942028985508, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8188405797101449, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8623188405797102, 0.625, 'Fare <= 15.373\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.8478260869565217, 0.575, 'Age <= 28.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.8405797101449275, 0.525, 'Age <= 16.0\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.8333333333333334, 0.475, 'Age <= 14.75\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8260869565217391, 0.425, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8405797101449275, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8478260869565217, 0.475, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.855072463768116, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8768115942028986, 0.575, 'Parch <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8695652173913043, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8840579710144928, 0.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8442028985507246, 0.675, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.927536231884058, 0.725, 'Age <= 32.0\nentropy = 0.998\nsamples = 57\nvalue = [27, 30]'),
#  Text(0.9202898550724637, 0.675, 'Fare <= 7.763\nentropy = 1.0\nsamples = 54\nvalue = [27, 27]'),
#  Text(0.8985507246376812, 0.625, 'Age <= 25.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8913043478260869, 0.575, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9057971014492754, 0.575, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9420289855072463, 0.625, 'Fare <= 10.825\nentropy = 0.995\nsamples = 48\nvalue = [26, 22]'),
#  Text(0.9202898550724637, 0.575, 'Fare <= 10.152\nentropy = 0.918\nsamples = 27\nvalue = [18, 9]'),
#  Text(0.9130434782608695, 0.525, 'Parch <= 0.5\nentropy = 0.954\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.9057971014492754, 0.475, 'Fare <= 9.84\nentropy = 0.902\nsamples = 22\nvalue = [15.0, 7.0]'),
#  Text(0.8985507246376812, 0.425, 'Fare <= 8.767\nentropy = 0.863\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.8913043478260869, 0.375, 'Fare <= 8.673\nentropy = 0.937\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.8840579710144928, 0.325, 'Age <= 27.5\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.8768115942028986, 0.275, 'Age <= 25.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.8695652173913043, 0.225, 'Fare <= 7.89\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.8623188405797102, 0.175, 'Age <= 18.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.855072463768116, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8695652173913043, 0.125, 'Age <= 23.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8623188405797102, 0.075, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8768115942028986, 0.075, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8768115942028986, 0.175, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8840579710144928, 0.225, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8913043478260869, 0.275, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8985507246376812, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9057971014492754, 0.375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9130434782608695, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9202898550724637, 0.475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.927536231884058, 0.525, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9637681159420289, 0.575, 'Fare <= 17.25\nentropy = 0.959\nsamples = 21\nvalue = [8, 13]'),
#  Text(0.9420289855072463, 0.525, 'Fare <= 13.438\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.9347826086956522, 0.475, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9492753623188406, 0.475, 'Fare <= 15.125\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.9420289855072463, 0.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9565217391304348, 0.425, 'Age <= 25.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.9492753623188406, 0.375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9637681159420289, 0.375, 'Age <= 27.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9565217391304348, 0.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9710144927536232, 0.325, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9855072463768116, 0.525, 'Fare <= 21.55\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.9782608695652174, 0.475, 'Age <= 30.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9710144927536232, 0.425, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9855072463768116, 0.425, 'Fare <= 19.262\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9782608695652174, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9927536231884058, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9927536231884058, 0.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9347826086956522, 0.675, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9492753623188406, 0.775, 'Age <= 55.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9420289855072463, 0.725, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9565217391304348, 0.725, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9710144927536232, 0.825, 'Parch <= 0.5\nentropy = 0.503\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.9637681159420289, 0.775, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9782608695652174, 0.775, 'Fare <= 31.331\nentropy = 0.391\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.9710144927536232, 0.725, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.9855072463768116, 0.725, 'Fare <= 32.881\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.9782608695652174, 0.675, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9927536231884058, 0.675, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape
# Out:
# (596, 10)

# %%
X_test.shape
# Out:
# (295, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %% [markdown]
# Сравниваем насколько хорошо наше дерево предсказывает ответы на train и test

# %% [markdown]
# Предсказываем число правильных ответов

# %%
clf.score(X, y)
# Out:
# 0.9797979797979798

# %%
clf = tree.DecisionTreeClassifier (criterion = 'entropy', max_depth = 3)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.score(X_train, y_train)
# Out:
# 0.8238255033557047

# %%
clf.score(X_test, y_test)
# Out:
# 0.8203389830508474

# %% [markdown]
# Обучаем 99 деревьев. для кажого из них предсказал события и сохранил точность классификации

# %%
scores_data = pd.DataFrame()

# %%
max_depth_values = range (1,100)
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier (criterion = 'entropy', max_depth=max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    
    temp_score_data = pd.DataFrame({'max_depth': [max_depth], 
                                    'train_score': [train_score], 
                                    'test_score': [test_score]})
    
    scores_data = pd.concat([scores_data, temp_score_data])

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score
# 0          1     0.781879    0.796610
# 0          2     0.805369    0.776271
# 0          3     0.823826    0.820339
# 0          4     0.833893    0.823729
# 0          5     0.840604    0.806780

# %%
scores_data_long = pd.melt(scores_data, id_vars = ['max_depth'], value_vars = ['train_score','test_score'], var_name = 'set_type', value_name = 'score')

sns.lineplot(x='max_depth', y='score', hue='set_type', data=scores_data_long)
# Out:
# <Axes: xlabel='max_depth', ylabel='score'>

# %% [markdown]
# анализ графика:
# train score:
# - растет с увеличением глубины дерева
# - что не всегда ведет к нахождению общих закономерностей в исследуемых данных
#
# test score:
# - изначально невелик (модель еще не доучилась)
# - на промежутке 3-5 score максимален (оптимальное состояние: закономерность с изученных данных переносится на новые)
# - с дальнейшим увеличением глубины test score начинает падать (переход от недообученности к переобученности)

# %%
from sklearn.model_selection import GridSearchCV

parametrs={'criterion':['gini', 'entropy'], 'max_depth': range(1, 30)}
clf=tree.DecisionTreeClassifier()
grid_search_cv_clf=GridSearchCV(clf, parametrs, cv=5)
grid_search_cv_clf.fit(X_train, y_train)
grid_search_cv_clf.best_params_
# Out:
# c:\Users\shcha\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'criterion': 'entropy', 'max_depth': 12}

# %%
parameters={'criterion':['gini', 'entropy'], 'max_depth':range(1, 150)}
grid_search_cv_clf=GridSearchCV(clf, parameters, cv=100)
